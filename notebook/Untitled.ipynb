# %%
# %load_ext tikzmagic

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (input_node_w111)                                 {$i_{11}$};
# \node    (input_node_w112)      [below=of input_node_w111] {$i_{12}$};
# \node    (input_node_w113)      [below=of input_node_w112] {$i_{13}$};
# \node    (input_node_w114)      [below=of input_node_w113] {$i_{14}$};
#
#
# \node    (activation_energy_z1) [right=of input_node_w111] {$i_{21}$};
# \node    (activation_energy_z2) [right=of input_node_w113] {$i_{22}$};
#
# \node    (input_node_w211)      [right=of activation_energy_z1]         {$i_{31}$};
# \node    (input_node_w212)      [below=of input_node_w211] {$i_{32}$};
# \node    (input_node_w213)      [below=of input_node_w212] {$i_{33}$};
#
# \node (cost_i31) [right=of input_node_w211] {$C(i_{31}) = \hat{y_{1}}$ compare to $y_{1}$};
# \node (cost_i32) [below=of cost_i31] {$C(i_{32}) = \hat{y_{2}}$ compare to $y_{2}$};
# \node (cost_i33) [below=of cost_i32] {$C(i_{33}) = \hat{y_{2}}$ compare to $y_{2}$};
#
#
# %Lines
# \draw (input_node_w111) -> (activation_energy_z1) node [midway, above, sloped] (Weight111) {$w_{111}$};
# \draw (input_node_w112) -> (activation_energy_z1) node [midway, above, sloped] (Weight112) {$w_{112}$};
# \draw (input_node_w113) -> (activation_energy_z1) node [midway, above, sloped] (Weight113) {$w_{113}$};
# \draw (input_node_w114) -> (activation_energy_z1) node [midway, above, sloped] (Weight114) {$w_{114}$};
#
# \draw (activation_energy_z1) -> (input_node_w211) node [midway, above, sloped] (Weight211) {$w_{211}$};
# \draw (activation_energy_z1) -> (input_node_w212) node [pos=0.4, above, sloped] (Weight212) {$w_{212}$};
# \draw (activation_energy_z1) -> (input_node_w213) node [pos=0.3, below, sloped] (Weight213) {$w_{213}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (input_node_w111)                                 {$i_{11}$};
# \node    (input_node_w112)      [below=of input_node_w111] {$i_{12}$};
# \node    (input_node_w113)      [below=of input_node_w112] {$i_{13}$};
# \node    (input_node_w114)      [below=of input_node_w113] {$i_{14}$};
#
#
# \node    (activation_energy_z1) [right=of input_node_w111] {$z_{11}$};
# \node    (activation_energy_z2) [below=of activation_energy_z1] {$z_{12}$};
#
# %Lines
# \draw (input_node_w111) -> (activation_energy_z1) node [midway, above, sloped] (Weight111) {$w_{111}$};
# \draw (input_node_w112) -> (activation_energy_z1) node [midway, above, sloped] (Weight112) {$w_{112}$};
# \draw (input_node_w113) -> (activation_energy_z1) node [midway, above, sloped] (Weight113) {$w_{113}$};
# \draw (input_node_w114) -> (activation_energy_z1) node [midway, below, sloped] (Weight114) {$w_{114}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
# \node    (z_1_activation_value) {$z_{11} = i_{11}*w_{111} + i_{12}*w_{112} + i_{13}*w_{113} + i_{14}*w_{114} + b_{11}$\hspace{15mm}$i_{21} = A(z_{11})$};
# \node    (z_2_activation_value) [below=of z_1_activation_value] {$z_{12} = i_{11}*w_{121} + i_{12}*w_{122} + i_{13}*w_{123} + i_{14}*w_{124} + b_{12}$\hspace{15mm}$i_{22} = A(z_{12})$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (activation_energy_i211)  {$i_{21}$};
# \node    (activation_energy_i222) [below=of activation_energy_i211] {$i_{22}$};
#
# \node    (input_node_w211)      [right=of activation_energy_i211]         {$z_{21}$};
# \node    (outputs)  [above=of input_node_w211]         {Outputs};
# \node    (input_node_w212)      [below=of input_node_w211] {$z_{22}$};
# \node    (input_node_w213)      [below=of input_node_w212] {$z_{23}$};
#
# %Lines
# \draw (activation_energy_i211) -> (input_node_w211) node [midway, above, sloped] (Weight211) {$w_{211}$};
# \draw (activation_energy_i211) -> (input_node_w212) node [pos=0.75, above, sloped] (Weight212) {$w_{212}$};
# \draw (activation_energy_i211) -> (input_node_w213) node [pos=0.7, above, sloped] (Weight213) {$w_{213}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# \node    (actiavtion_function_z_3)   {$z_{21} = i_{21}*w_{211} + i_{22}*w_{212} + b_{21}$\hspace{15mm}$i_{31} = A(z_{21})$};
# \node    (actiavtion_function_z_4) [below=of actiavtion_function_z_3] {$z_{22} = i_{21}*w_{221} + i_{22}*w_{222} + b_{22}$\hspace{15mm}$i_{32} = A(z_{22})$};
# \node    (actiavtion_function_z_5) [below=of actiavtion_function_z_4] {$z_{23} = i_{21}*w_{231} + i_{22}*w_{232} + b_{23}$\hspace{15mm}$i_{33} = A(z_{23})$};

# %%
# %%tikz -f svg -l positioning
# \node (cost_i_311) {$C(i_{31}) = \hat{y_1}$};
# \node (cost_i_312) [below=of cost_i_311] {$C(i_{32}) = \hat{y_2}$};
# \node (cost_i_313) [below=of cost_i_312] {$C(i_{33}) = \hat{y_3}$};

# %%
# %%tikz -f svg -l positioning
# \node (deriv_cost_w_211)                             {$\frac{\delta C}{\delta w_{211}} = \frac{\delta C}{\delta i_{31}}*\frac{\delta i_{31}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta w_{211}}$};
# \node (deriv_cost_w_212) [below of=deriv_cost_w_211] {$\frac{\delta C}{\delta w_{212}} = \frac{\delta C}{\delta i_{31}}*\frac{\delta i_{31}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta w_{212}}$};
# \node (deriv_cost_w_221) [below of=deriv_cost_w_212] {$\frac{\delta C}{\delta w_{221}} = \frac{\delta C}{\delta i_{32}}*\frac{\delta i_{32}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta w_{221}}$};
# \node (deriv_cost_w_222) [below of=deriv_cost_w_221] {$\frac{\delta C}{\delta w_{222}} = \frac{\delta C}{\delta i_{32}}*\frac{\delta i_{32}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta w_{221}}$};
# \node (deriv_cost_w_231) [below of=deriv_cost_w_222] {$\frac{\delta C}{\delta w_{231}} = \frac{\delta C}{\delta i_{33}}*\frac{\delta i_{33}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta w_{231}}$};
# \node (deriv_cost_w_232) [below of=deriv_cost_w_231] {$\frac{\delta C}{\delta w_{232}} = \frac{\delta C}{\delta i_{33}}*\frac{\delta i_{33}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta w_{232}}$};

# %%
# %%tikz -f svg -l positioning
# \node[align=left] (deriv_cost_w_111) {$\frac{\delta C}{\delta w_{111}} = \frac{\delta C}{\delta i_{31}}*\frac{\delta i_{31}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta i_{21}}*\frac{\delta i_{21}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}+$};
# \node[align=left] (derv_cost_w_111_cont) [below=of deriv_cost_w_111]   {\hspace{10mm}$\frac{\delta C}{\delta i_{32}}*\frac{\delta i_{32}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta i_{21}}*\frac{\delta i_{21}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}+$};
# \node[align=left] (derv_cost_w_111_cont_2) [below=of derv_cost_w_111_cont]   {\hspace{10mm}$\frac{\delta C}{\delta i_{33}}*\frac{\delta i_{33}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta i_{21}}*\frac{\delta i_{21}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}$};
