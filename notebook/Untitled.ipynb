# %%
# %load_ext tikzmagic

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (1_input_node_w111)                                 {$i_1$};
# \node    (1_input_node_w112)      [below=of 1_input_node_w111] {$i_2$};
# \node    (1_input_node_w113)      [below=of 1_input_node_w112] {$i_3$};
# \node    (1_input_node_w114)      [below=of 1_input_node_w113] {$i_4$};
#
# \node    (1_activation_energy_z1) [right=of 1_input_node_w111] {$\alpha_{11}$};
# \node    (1_activation_energy_z2) [right=of 1_input_node_w113] {$\alpha_{12}$};
#
# \node    (1_input_node_w211)      [right=of 1_activation_energy_z1]         {$\alpha_{21}$};
# \node    (1_input_node_w212)      [below=of 1_input_node_w211] {$\alpha_{22}$};
# \node    (1_input_node_w213)      [below=of 1_input_node_w212] {$\alpha_{23}$};
#
# \node (1_cost_i31) [right=of 1_input_node_w211] {$\alpha_{21} = \hat{y_{1}}$ compare to $y_1$ via $C(\hat{y_1},y_{1})$};
# \node (1_cost_i32) [below=of 1_cost_i31] {$\alpha_{22} = \hat{y_{2}}$ compare to $y_{2}$ via $C(\hat{y_2},y_{2})$};
# \node (1_cost_i33) [below=of 1_cost_i32] {$\alpha_{23} = \hat{y_{2}}$ compare to $y_{2}$ via $C(\hat{y_3},y_{3})$};
#
#
# %Lines
# \draw (1_input_node_w111) -> (1_activation_energy_z1) node [midway, above, sloped] (Weight111) {$w_{111}$};
# \draw (1_input_node_w112) -> (1_activation_energy_z1) node [midway, above, sloped] (Weight112) {$w_{112}$};
# \draw (1_input_node_w113) -> (1_activation_energy_z1) node [midway, above, sloped] (Weight113) {$w_{113}$};
# \draw (1_input_node_w114) -> (1_activation_energy_z1) node [midway, above, sloped] (Weight114) {$w_{114}$};
#
# \draw (1_activation_energy_z1) -> (1_input_node_w211) node [midway, above, sloped] (Weight211) {$w_{211}$};
# \draw (1_activation_energy_z1) -> (1_input_node_w212) node [pos=0.4, above, sloped] (Weight212) {$w_{212}$};
# \draw (1_activation_energy_z1) -> (1_input_node_w213) node [pos=0.3, below, sloped] (Weight213) {$w_{213}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (2_input_node_w111)                                 {$i_{1}$};
# \node    (2_input_node_w112)      [below=of 2_input_node_w111] {$i_{2}$};
# \node    (2_input_node_w113)      [below=of 2_input_node_w112] {$i_{3}$};
# \node    (2_input_node_w114)      [below=of 2_input_node_w113] {$i_{4}$};
#
#
# \node    (2_activation_energy_z1) [right=of 2_input_node_w111] {$z_{11}$};
# \node    (2_activation_energy_z2) [below=of 2_activation_energy_z1] {$z_{12}$};
#
# %Lines
# \draw (2_input_node_w111) -> (2_activation_energy_z1) node [midway, above, sloped] (Weight111) {$w_{111}$};
# \draw (2_input_node_w112) -> (2_activation_energy_z1) node [midway, above, sloped] (Weight112) {$w_{112}$};
# \draw (2_input_node_w113) -> (2_activation_energy_z1) node [midway, above, sloped] (Weight113) {$w_{113}$};
# \draw (2_input_node_w114) -> (2_activation_energy_z1) node [midway, below, sloped] (Weight114) {$w_{114}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
# \node    (3_z_1_activation_value) {$z_{11} = i_1*w_{111} + i_2*w_{112} + i_3*w_{113} + i_4*w_{114} + b_{11}$\hspace{15mm}$\alpha_{11} = A(z_{11})$};
# \node    (3_z_2_activation_value) [below=of 3_z_1_activation_value] {$z_{12} = i_1*w_{121} + i_2*w_{122} + i_3*w_{123} + i_4*w_{124} + b_{12}$\hspace{15mm}$\alpha_{12} = A(z_{12})$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# %Nodes
# \node    (4_activation_energy_i211)  {$\alpha_{11}$};
# \node    (4_activation_energy_i222) [below=of 4_activation_energy_i211] {$\alpha_{12}$};
#
# \node    (4_input_node_w211)      [right=of 4_activation_energy_i211]         {$z_{21}$};
# \node    (4_input_node_w212)      [below=of 4_input_node_w211] {$z_{22}$};
# \node    (4_input_node_w213)      [below=of 4_input_node_w212] {$z_{23}$};
#
# %Lines
# \draw (4_activation_energy_i211) -> (4_input_node_w211) node [midway, above, sloped] (Weight211) {$w_{211}$};
# \draw (4_activation_energy_i211) -> (4_input_node_w212) node [pos=0.75, above, sloped] (Weight212) {$w_{212}$};
# \draw (4_activation_energy_i211) -> (4_input_node_w213) node [pos=0.7, above, sloped] (Weight213) {$w_{213}$};

# %%
# %%tikz -f svg -l positioning
#
# \centering
#
# \node    (5_aciavtion_function_z_3)   {$z_{21} = \alpha_{11}*w_{211} + \alpha_{12}*w_{212} + b_{21}$\hspace{15mm}$\alpha_{21} = A(z_{21})$};
# \node    (5_aciavtion_function_z_4) [below=of 5_aciavtion_function_z_3] {$z_{22} = \alpha_{11}*w_{221} + \alpha_{12}*w_{222} + b_{22}$\hspace{15mm}$\alpha_{22} = A(z_{22})$};
# \node    (5_aciavtion_function_z_5) [below=of 5_aciavtion_function_z_4] {$z_{23} = \alpha_{11}*w_{231} + \alpha_{12}*w_{232} + b_{23}$\hspace{15mm}$\alpha_{23} = A(z_{23})$};

# %%
# %%tikz -f svg -l positioning
# \node (6_acivation_value_i_311) {$\alpha_{21} = \hat{y_1}$};
# \node (6_acivation_value_i_312) [below=of 6_acivation_value_i_311] {$\alpha_{22} = \hat{y_2}$};
# \node (6_acivation_value_i_313) [below=of 6_acivation_value_i_312] {$\alpha_{23} = \hat{y_3}$};
# \node (6_cost_1) [right=of 6_acivation_value_i_311] {$C(\hat{y_1},y_1)$};
# \node (6_cost_2) [right=of 6_acivation_value_i_312] {$C(\hat{y_2},y_2)$};
# \node (6_cost_3) [right=of 6_acivation_value_i_313] {$C(\hat{y_3},y_3)$};

# %%
# %%tikz -f svg -l positioning
# \node (7_deriv_cost_w_211)                             {$\frac{\delta C}{\delta w_{211}} = \frac{\delta C}{\delta \alpha_{21}}*\frac{\delta \alpha_{21}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta w_{211}}$};
# \node (7_deriv_cost_w_212) [below of=7_deriv_cost_w_211] {$\frac{\delta C}{\delta w_{212}} = \frac{\delta C}{\delta \alpha_{21}}*\frac{\delta \alpha_{21}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta w_{212}}$};
# \node (7_deriv_cost_w_221) [below of=7_deriv_cost_w_212] {$\frac{\delta C}{\delta w_{221}} = \frac{\delta C}{\delta \alpha_{22}}*\frac{\delta \alpha_{22}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta w_{221}}$};
# \node (7_deriv_cost_w_222) [below of=7_deriv_cost_w_221] {$\frac{\delta C}{\delta w_{222}} = \frac{\delta C}{\delta \alpha_{22}}*\frac{\delta \alpha_{22}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta w_{222}}$};
# \node (7_deriv_cost_w_231) [below of=7_deriv_cost_w_222] {$\frac{\delta C}{\delta w_{231}} = \frac{\delta C}{\delta \alpha_{23}}*\frac{\delta \alpha_{23}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta w_{231}}$};
# \node (7_deriv_cost_w_232) [below of=7_deriv_cost_w_231] {$\frac{\delta C}{\delta w_{232}} = \frac{\delta C}{\delta \alpha_{23}}*\frac{\delta \alpha_{23}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta w_{232}}$};

# %%
# %%tikz -f svg -l positioning
# \node (8_deriv_cost_w_211)                             {$\frac{\delta C}{\delta w_{211}} = \frac{\delta C}{\delta \alpha_{21}}*A'(z_{21})*\alpha_{11}$};
# \node (8_deriv_cost_w_212) [below of=8_deriv_cost_w_211] {$\frac{\delta C}{\delta w_{212}} = \frac{\delta C}{\delta \alpha_{21}}*A'(z_{21})*\alpha_{12}$};
# \node (8_deriv_cost_w_221) [below of=8_deriv_cost_w_212] {$\frac{\delta C}{\delta w_{221}} = \frac{\delta C}{\delta \alpha_{22}}*A'(z_{22})*\alpha_{11}$};
# \node (8_deriv_cost_w_222) [below of=8_deriv_cost_w_221] {$\frac{\delta C}{\delta w_{222}} = \frac{\delta C}{\delta \alpha_{22}}*A'(z_{22})*\alpha_{12}$};
# \node (8_deriv_cost_w_231) [below of=8_deriv_cost_w_222] {$\frac{\delta C}{\delta w_{231}} = \frac{\delta C}{\delta \alpha_{23}}*A'(z_{23})*\alpha_{11}$};
# \node (8_deriv_cost_w_232) [below of=8_deriv_cost_w_231] {$\frac{\delta C}{\delta w_{232}} = \frac{\delta C}{\delta \alpha_{23}}*A'(z_{23})*\alpha_{12}$};

# %%
# %%tikz -f svg -l positioning
# \node[align=left] (9_deriv_cost_w_111) {$\frac{\delta C}{\delta w_{111}} = \frac{\delta C}{\delta \alpha_{21}}*\frac{\delta \alpha_{21}}{\delta z_{21}}*\frac{\delta z_{21}}{\delta \alpha_{11}}*\frac{\delta \alpha_{11}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}+$};
# \node[align=left] (9_deriv_cost_w_111_cont) [below=of 9_deriv_cost_w_111]   {\hspace{10mm}$\frac{\delta C}{\delta \alpha_{22}}*\frac{\delta \alpha_{22}}{\delta z_{22}}*\frac{\delta z_{22}}{\delta \alpha_{11}}*\frac{\delta \alpha_{11}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}+$};
# \node[align=left] (9_deriv_cost_w_111_cont_2) [below=of 9_deriv_cost_w_111_cont]   {\hspace{10mm}$\frac{\delta C}{\delta \alpha_{23}}*\frac{\delta \alpha_{23}}{\delta z_{23}}*\frac{\delta z_{23}}{\delta \alpha_{11}}*\frac{\delta \alpha_{11}}{\delta z_{11}}*\frac{\delta z_{11}}{\delta w_{111}}$};

# %%
# %%tikz -f svg -l positioning
# \node[align=left] (10_deriv_cost_w_111) {$\frac{\delta C}{\delta w_{111}} = \frac{\delta C}{\delta \alpha_{21}}*A'(z_{21})*w_{211}*A'(z_{11})*i_1+$};
# \node[align=left] (10_deriv_cost_w_111_cont) [below=of 10_deriv_cost_w_111]   {\hspace{10mm}$\frac{\delta C}{\delta \alpha_{22}}*A'(z_{22})*w_{221}*A'(z_{11})*i_1+$};
# \node[align=left] (10_deriv_cost_w_111_cont_2) [below=of 10_deriv_cost_w_111_cont]   {\hspace{10mm}$\frac{\delta C}{\delta \alpha_{23}}*A'(z_{23})*w_{231}*A'(z_{11})*i_1$};
